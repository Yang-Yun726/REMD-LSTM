# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from pylab import *

mpl.rcParams['font.sans-serif'] = ['SimHei']
#指定默认字体
#cpu1值
c1= (113.047547,10.632382,8.164515368)#LSTM
c2= (146.3287038,12.09664018,10.07427042)#ARIMA
c3= (3812.999027,61.74948605,48.45738311)#SVM
c4= (256.7095177,16.02215709,13.07233663)#remd-lstm
#c5= (0.795951,0.892161,0.75638)#wnn
#cpu2值
r1= (0.0829002,0.287923949,0.233092988)
r2= (0.264339198,0.514139279,0.422464369)
r3= (0.094013468,0.306616158,0.256026693)
r4= (0.105907913,0.32543496,0.237412812)
#r5= (0.373681,0.611294,0.480463)
#memory1
f1= (5.03553E-05,0.007096145,0.005454375)
f2= (6.73191E-05,0.008204823,0.006328749)
f3= (0.001248157,0.035329268,0.033543932)
f4= (0.001619124,0.040238334,0.021968064)
#f5=(0.072055,0.268431,0.214475)
#memory2
d4=(0.037230024,0.192950832,0.145021608)
d2=(0.064871672,0.254699179,0.198151327)
d3=(0.033469484,0.182946671,0.154379028)
d1=(0.016662275,0.129082436,0.106322476)
#d5=(0.058526,0.241921,0.198696)
ind = np.arange(3) # the x locations for the groups
width = 0.15 # the width of the bars
labels = ['MSE', 'RMSE', 'MAE']
plt.figure(dpi=800)#dpi=300
plt.subplot(221)
#plt.bar(ind , c101, width , color='y')
#plt.bar(ind + width, c102, width, color='b')
plt.bar(ind+width, c1, width, color='g', label='REMD-LSTM')
plt.bar(ind+2*width, c2, width,color='b', label='ARIMA')
plt.bar(ind + 3*width, c3, width, color='y',label='SVM')
plt.bar(ind + 4*width, c4, width, color='r',label='LSTM')
#plt.bar(ind + 5*width, c5, width,label='WNN')
plt.ylim((0, 300))
plt.xticks(ind+3*width,labels,fontsize=7)
plt.legend(loc='upper right',prop = {'size':4})
plt.xlabel('Stock',fontsize=10)
plt.ylabel('Value',fontsize=8)
plt.title('Comparative Results',fontsize=8)

plt.subplot(222)
#plt.bar(ind , c101, width , color='y')
#plt.bar(ind + width, c102, width, color='b')
plt.bar(ind+width, r1, width, color='g', label='REMD-LSTM')
plt.bar(ind+2*width, r2, width,color='b', label='ARIMA')
plt.bar(ind + 3*width, r3, width, color='y',label='SVM')
plt.bar(ind + 4*width, r4, width, color='r',label='LSTM')
#plt.bar(ind + 5*width, r5, width,label='WNN')
plt.ylim((0, 0.6))
plt.xticks(ind+3*width,labels,fontsize=7)
plt.legend(loc='upper right',prop = {'size':4})
plt.xlabel('CPU',fontsize=10)
plt.ylabel('Value',fontsize=8)
plt.title('Comparative Results',fontsize=8)

plt.subplot(223)
#plt.bar(ind , c101, width , color='y')
#plt.bar(ind + width, c102, width, color='b')
plt.bar(ind+width, f1, width, color='g', label='REMD-LSTM')
plt.bar(ind+2*width, f2, width,color='b', label='ARIMA')
plt.bar(ind + 3*width, f3, width, color='y',label='SVM')
plt.bar(ind + 4*width, f4, width, color='r',label='LSTM')
#plt.bar(ind + 5*width, f5, width,label='WNN')
plt.ylim((0, 0.05))
plt.xticks(ind+3*width,labels,fontsize=7)
plt.legend(loc='upper right',prop = {'size':4})
plt.xlabel('Commodity',fontsize=10)
plt.ylabel('Value',fontsize=8)
plt.title('Comparative Results',fontsize=8)

plt.subplot(224)
#plt.bar(ind , c101, width , color='y')
#plt.bar(ind + width, c102, width, color='b')
plt.bar(ind+width, d1, width, color='g', label='REMD-LSTM')
plt.bar(ind+2*width, d2, width,color='b', label='ARIMA')
plt.bar(ind + 3*width, d3, width, color='y',label='SVM')
plt.bar(ind + 4*width, d4, width, color='r',label='LSTM')
#plt.bar(ind + 5*width, d5, width,label='WNN')
plt.ylim((0, 0.3))
plt.xticks(ind+3*width,labels,fontsize=7)
plt.legend(loc='upper right',prop = {'size':4})
plt.xlabel('Thyroid',fontsize=10)
plt.ylabel('Value',fontsize=8)
plt.title('Comparative Results',fontsize=8)
plt.tight_layout()#调整子图之间的距离
plt.show()
